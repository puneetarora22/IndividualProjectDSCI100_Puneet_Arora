# %% [markdown]
# ### 1. Data Description

# %%
library(tidyverse)
library(tidymodels)

# %% [markdown]
# To determine the characteristics of the dataset, we should first read the datasets in R and then use the ```glimpse()```

# %%
players <- read_csv("projectData/players.csv")
sessions <- read_csv("projectData/sessions.csv")

glimpse(players)
glimpse(sessions)

# %% [markdown]
# The ```players``` dataset has the following characteristics:
# - **Number of observations** = 196
# - **Number of variables** = 7
# -
